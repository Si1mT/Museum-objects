# %% [markdown]
# <a href="https://colab.research.google.com/github/Si1mT/Museum-objects/blob/main/Museum_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Files
#
# unique_types.csv
#
# This file represents the unique museum object types that can be predicted. All types are in Estonian language.
#
# train.csv
#
# Training set that should be used to build your machine learning models. The training set includes both the descriptive variables of the museum object and the ground truth about the type of the object.
#
# test.csv
#
# Test set should be used to see how well your model performs on unseen data. The test set includes the descriptive variables about the objects but not the type of the object. It is your job to predict it using the model you built on the training data!
#
# sample_submission.csv
#
# An example of what the submission file should look like. For every row in the test data, submission files should contain two columns: id (representing the id of the museum object) and type (representing the type of the object). Example format:
#
# id, type
#
# 2652198, foto
#
# 3851731, kiri
#
# Etc.

# %% [markdown]
# Thus, we ask you to help us by creating a smart model to fill in the gaps in the data based on existing descriptive variables.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing Test and Train data 
import pandas as pd

unique_types = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/unique_types.csv")
datatest = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/test.csv")
df = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/train.csv")

# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#         id                         full_nr  \
# 0   232170  ETMM _ 12150:115 Aj 118:44/M20
# 1  2251378   ETMM _ 12584:19 M 102:1/13:13
# 2  2070466                             NaN
# 3  4085096               ETMM _ Fk 41691/k
# 4  2697904      ETMM _ 9424 Mo 238:1/62:05
#
#                                                 name       ks      material  \
# 0           Kuno Areng, Bremerhaveni Festwoche medal    118.0        metall
# 1   Foto-Villem Kapp,foto pühendusega Armilde M,1937    102.0  fotomaterjal
# 2                                                NaN      NaN           NaN
# 3  Metspart, Noorsooteater, 1969, osades: Hedvig ...  41691.0  fotomaterjal
# 4  Kiri: Rahvapillimehed: Viiul: Jüri Saal: Kiri ...    238.0         paber
#
#   commentary                event_type          location       start  end  \
# 0        NaN                festivalid  linn Bremerhaven        1979  NaN
# 1        NaN  filmindus ja fotograafia               NaN        1938  NaN
# 2        NaN                       NaN               NaN         NaN  NaN
# 3        NaN                    teater               NaN  18.09.1969  NaN
# 4        NaN                       NaN               NaN         NaN  NaN
#
#   before_Christ country_and_unit   participants_role    participant parish  \
# 0            ei       Saksamaa               osaleja    Areng, Kuno    NaN
# 1            ei                                  NaN            NaN    NaN
# 2           NaN              NaN                 NaN            NaN    NaN
# 3            ei                   seosorganisatsioon  Noorsooteater    NaN
# 4           NaN              NaN                 NaN            NaN    NaN
#
#   text class technique    parameter        unit value museum_abbr  \
# 0  NaN   NaN       NaN     läbimõõt          cm     4        ETMM
# 1  NaN   NaN       NaN          NaN         NaN   NaN        ETMM
# 2  NaN   NaN       NaN          NaN         NaN   NaN          AM
# 3  NaN   NaN       NaN  filmikaader  60 x 60 mm     1        ETMM
# 4  NaN   NaN  käsikiri          NaN         NaN   NaN        ETMM
#
#   musealia_mark  musealia_seria_nr  musealia_queue_nr musealia_additional_nr  \
# 0             _            12150.0              115.0                    NaN
# 1             _            12584.0               19.0                    NaN
# 2           NaN                NaN                NaN                    NaN
# 3             _                NaN                NaN                    NaN
# 4             _             9424.0                NaN                    NaN
#
#   collection_mark  collection_queue_nr collection_additional_nr  \
# 0              Aj                 44.0                      M20
# 1               M                  1.0                    13:13
# 2               F                 52.0                      NaN
# 3              Fk                  NaN                        k
# 4              Mo                  1.0                 62:05:00
#
#    element_count                                             legend  \
# 0            1.0                                                NaN
# 1            1.0  Fotod Villem Kapi ja Juhan Aaviku kogu-\ndesse...
# 2            1.0                                                NaN
# 3            1.0                                                NaN
# 4            1.0                              Rahvapillimehed Mo238
#
#    is_original              initial_info damages     state color  \
# 0          1.0  Festwoche- Breemenhaven      NaN       hea  hall
# 1          NaN                       NaN     NaN       hea   NaN
# 2          NaN                       NaN     NaN       hea   NaN
# 3          1.0                  TB080321     NaN  rahuldav   NaN
# 4          1.0                       NaN     NaN  rahuldav   NaN
#
#                                    additional_text          type
# 0  KUTTER ASTARTE -SCHIFFERGILDE BREMENHAVEN E. V.         medal
# 1                                              NaN          foto
# 2                                              NaN          foto
# 3                                              NaN  fotonegatiiv
# 4                                              NaN          kiri

# %%
datatest.head()
# Out:
#         id                             full_nr  \
# 0  2652198                                 NaN
# 1  3851731                                 NaN
# 2  1211338              AM _ 37617:3 TE 4372:3
# 3   231244  ETMM _ 12011:206/22 Aj 115:33/M427
# 4  2523607                   AM _ 29147:2256 M
#
#                                   name      ks               material  \
# 0                                  NaN     NaN                    NaN
# 1                                  NaN     NaN                    NaN
# 2  Kott, rahvusmustriga tenniste jaoks  4372.0  sünteetiline materjal
# 3  Laine Karindi segakoori Tungal märk   115.0                  email
# 4                            1/2 örtug     NaN                biljoon
#
#   commentary               event_type        location       start         end  \
# 0        NaN                laulupeod             NaN  27.06.1969  29.06.1969
# 1        NaN              kirjutamine    linn Wroclaw  15.12.1987         NaN
# 2        NaN    <RIIETUS JA LISANDID>             NaN         NaN         NaN
# 3        NaN  koorilauluga tegelemine             NaN         NaN         NaN
# 4        NaN             valmistamine  linn Stockholm        1512        1520
#
#   before_Christ country_and_unit participants_role        participant parish  \
# 0            ei   Eesti  Tallinn               NaN                NaN    NaN
# 1            ei          Poola           adressaat        O'Ya, Bruno    NaN
# 2           NaN                                NaN                NaN    NaN
# 3           NaN          Eesti            dirigent     Karindi, Laine    NaN
# 4           NaN         Rootsi          emiteerija  Sture  jun., Sten    NaN
#
#                              text                    class  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2   Rahvusmustriga tenniste kott.  nimetus lähtedokumendil
# 3                             NaN                      NaN
# 4                             NaN                      NaN
#
#                     technique       parameter  unit value museum_abbr  \
# 0                         NaN             NaN   NaN   NaN        ETMM
# 1                         NaN  dokumendi maht  leht     1        ETMM
# 2  (kinni-/ kokku-) õmblemine          pikkus    cm    41          AM
# 3                         NaN             NaN   NaN   NaN        ETMM
# 4                         NaN            kaal     g  0.77          AM
#
#   musealia_mark  musealia_seria_nr  musealia_queue_nr musealia_additional_nr  \
# 0             _             8811.0                NaN                    NaN
# 1             _            12073.0               46.0                      9
# 2             _            37617.0                3.0                    NaN
# 3             _            12011.0              206.0                     22
# 4             _            29147.0             2256.0                    NaN
#
#   collection_mark  collection_queue_nr collection_additional_nr  \
# 0              Mo                  1.0                 41:04:00
# 1               T                  1.0                 41:09:00
# 2              TE                  3.0                      NaN
# 3              Aj                 33.0                     M427
# 4               M                  NaN                      NaN
#
#    element_count                                             legend  \
# 0            1.0                                                NaN
# 1            1.0                                                NaN
# 2            1.0  Rahvusmustriga tennised on valmistatud 2009.a....
# 3            1.0                                                NaN
# 4            1.0                                                NaN
#
#    is_original                                       initial_info damages  \
# 0          1.0                                                NaN     NaN
# 1          1.0                                          1977-2002     NaN
# 2          1.0  Valgest sünteetilisest materjalist, punaste pa...     NaN
# 3          1.0            TUNGAL - segakoor; saadud Linda Targolt     NaN
# 4          NaN                               aardeleid metallnõus     NaN
#
#        state  color                                    additional_text
# 0        hea    NaN                                                NaN
# 1        hea    NaN                                                NaN
# 2        hea    NaN  Tenniste kott, valgest sünteetilisest materjal...
# 3        hea  valge            TUNGAL - segakoor; saadud Linda Targolt
# 4  määramata    NaN                                                NaN

# %%
unique_types.head(60)
# Out:
#                              type
# 0                            foto
# 1                    fotonegatiiv
# 2            kavand/joonis/eskiis
# 3                          plakat
# 4                            kava
# 5             arheoloogiline leid
# 6                            kiri
# 7                          raamat
# 8                        käsikiri
# 9                        dokument
# 10                         noodid
# 11                       graafika
# 12           pitser/templijäljend
# 13                           münt
# 14  käsikiri, laul/ vokaalmuusika
# 15             digitaalne kujutis
# 16                      postkaart
# 17                    väiketrükis
# 18                        ajakiri
# 19                        ajaleht
# 20                          medal
# 21                          kutse
# 22                      telegramm
# 23                  helisalvestis
# 24          käsikiri, muusikateos
# 25                    diapositiiv
# 26                      silt/märk
# 27                      joonistus
# 28                foto, postkaart
# 29                       kalender
# 30                     karikatuur
# 31                   fotomaterjal
# 32               aukiri/auaadress
# 33                       nõu/anum
# 34                         pitsat
# 35                      trükinoot
# 36              muusikainstrument
# 37                          album
# 38                          paber
# 39                           maal
# 40     fotonegatiiv, fotonegatiiv
# 41                          kleit
# 42                      skulptuur
# 43                           kott
# 44                  kaustik/vihik
# 45                      lint/pael
# 46                        märkmed
# 47                           nukk
# 48                kiri, postkaart
# 49                     lina/linik
# 50                            ehe
# 51                    laegas/karp
# 52               käsikiri, noodid
# 53                         pakend
# 54                      tunnistus

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#impordime testi tegemiseks vajalikut teegi
from scipy import stats

#fikseerime juhuslikkuse, et tulemused oleks korratavad
rng = np.random.default_rng(seed=68)

# %%
#visualiseerime iga tunnuse histogrammina
df.hist(figsize=(10,10), bins=15, grid=False);

# %%
#Visualiseerimine tunnustevahelist korrelatsiooni
plt.figure(figsize = (10,10))
plt.title("Correlation Heatmap")
sns.heatmap(df.corr(), annot=True, cmap="Blues", cbar=False);

# %%
#Teeme täpsema joonise, visualiseerides seosesid paarikaupa
sns.pairplot(df);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        14000 non-null  int64
#  1   full_nr                   9012 non-null   object
#  2   name                      9012 non-null   object
#  3   ks                        8816 non-null   float64
#  4   material                  9012 non-null   object
#  5   commentary                440 non-null    object
#  6   event_type                9302 non-null   object
#  7   location                  1239 non-null   object
#  8   start                     5920 non-null   object
#  9   end                       1247 non-null   object
#  10  before_Christ             5435 non-null   object
#  11  country_and_unit          9302 non-null   object
#  12  participants_role         6234 non-null   object
#  13  participant               6234 non-null   object
#  14  parish                    14 non-null     object
#  15  text                      229 non-null    object
#  16  class                     229 non-null    object
#  17  technique                 5691 non-null   object
#  18  parameter                 6571 non-null   object
#  19  unit                      6571 non-null   object
#  20  value                     6571 non-null   object
#  21  museum_abbr               13998 non-null  object
#  22  musealia_mark             10356 non-null  object
#  23  musealia_seria_nr         10010 non-null  float64
#  24  musealia_queue_nr         2209 non-null   float64
#  25  musealia_additional_nr    483 non-null    object
#  26  collection_mark           13998 non-null  object
#  27  collection_queue_nr       10440 non-null  float64
#  28  collection_additional_nr  7506 non-null   object
#  29  element_count             14000 non-null  float64
#  30  legend                    3098 non-null   object
#  31  is_original               11779 non-null  float64
#  32  initial_info              1613 non-null   object
#  33  damages                   1160 non-null   object
#  34  state                     14000 non-null  object
#  35  color                     451 non-null    object
#  36  additional_text           3062 non-null   object
#  37  type                      14000 non-null  object
# dtypes: float64(6), int64(1), object(31)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#                  id             ks  musealia_seria_nr  musealia_queue_nr  \
# count  1.400000e+04    8816.000000       10010.000000        2209.000000
# mean   2.923072e+06    6441.173888       11216.157343         273.129018
# std    8.626119e+05   15473.738824        6850.283512         398.997111
# min    1.956300e+05       1.000000           2.000000           1.000000
# 25%    2.328927e+06      53.000000        7315.000000          25.000000
# 50%    2.870586e+06     416.000000        9951.500000         122.000000
# 75%    3.620546e+06    3517.000000       12582.000000         329.000000
# max    4.322668e+06  123130.000000      111380.000000        4268.000000
#
#        collection_queue_nr  element_count   is_original
# count         10440.000000   14000.000000  11779.000000
# mean            210.702969       1.003071      0.965362
# std             747.038120       0.155585      0.182869
# min               1.000000       1.000000      0.000000
# 25%               1.000000       1.000000      1.000000
# 50%               2.000000       1.000000      1.000000
# 75%              52.000000       1.000000      1.000000
# max            6320.000000      14.000000      1.000000

# %%
import numpy as np
from warnings import filterwarnings
from collections import Counter
import plotly.express as px
import pandas as pd
import numpy as np
import re
import missingno as msno
from functools import partial
import seaborn as sns

colors_blue = ["#132C33", "#264D58", '#17869E', '#51C4D3', '#B4DBE9']
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

# %%
from matplotlib import cm

# %%
fig = msno.matrix(df,color=(0,0.5,0.5))

# %%
df.isnull().sum()
# Out:
# id                              0
# full_nr                      4988
# name                         4988
# ks                           5184
# material                     4988
# commentary                  13560
# event_type                   4698
# location                    12761
# start                        8080
# end                         12753
# before_Christ                8565
# country_and_unit             4698
# participants_role            7766
# participant                  7766
# parish                      13986
# text                        13771
# class                       13771
# technique                    8309
# parameter                    7429
# unit                         7429
# value                        7429
# museum_abbr                     2
# musealia_mark                3644
# musealia_seria_nr            3990
# musealia_queue_nr           11791
# musealia_additional_nr      13517
# collection_mark                 2
# collection_queue_nr          3560
# collection_additional_nr     6494
# element_count                   0
# legend                      10902
# is_original                  2221
# initial_info                12387
# damages                     12840
# state                           0
# color                       13549
# additional_text             10938
# type                            0
# dtype: int64

# %%
print(f'Before dropping missing values, we have {df.shape[0]} instances')

df_dropped = df.dropna()
print(f'After dropping missing values, we have {df_dropped.shape[0]} instances')

# to see how mnay instances we have lost
print(f'We have lost {df.shape[0]-df_dropped.shape[0]} instances, which means {round((df.shape[0]-df_dropped.shape[0])/ (float(df.shape[0])),2)*100}% data we have lost')
# Out:
# Before dropping missing values, we have 14000 instances
# After dropping missing values, we have 0 instances
# We have lost 14000 instances, which means 100.0% data we have lost

# %%
print(df.dtypes)
df.isnull().sum()
# Out:
# id                            int64
# full_nr                      object
# name                         object
# ks                          float64
# material                     object
# commentary                   object
# event_type                   object
# location                     object
# start                        object
# end                          object
# before_Christ                object
# country_and_unit             object
# participants_role            object
# participant                  object
# parish                       object
# text                         object
# class                        object
# technique                    object
# parameter                    object
# unit                         object
# value                        object
# museum_abbr                  object
# musealia_mark                object
# musealia_seria_nr           float64
# musealia_queue_nr           float64
# musealia_additional_nr       object
# collection_mark              object
# collection_queue_nr         float64
# collection_additional_nr     object
# element_count               float64
# legend                       object
# is_original                 float64
# initial_info                 object
# damages                      object
# state                        object
# color                        object
# additional_text              object
# type                         object
# dtype: object
# id                              0
# full_nr                      4988
# name                         4988
# ks                           5184
# material                     4988
# commentary                  13560
# event_type                   4698
# location                    12761
# start                        8080
# end                         12753
# before_Christ                8565
# country_and_unit             4698
# participants_role            7766
# participant                  7766
# parish                      13986
# text                        13771
# class                       13771
# technique                    8309
# parameter                    7429
# unit                         7429
# value                        7429
# museum_abbr                     2
# musealia_mark                3644
# musealia_seria_nr            3990
# musealia_queue_nr           11791
# musealia_additional_nr      13517
# collection_mark                 2
# collection_queue_nr          3560
# collection_additional_nr     6494
# element_count                   0
# legend                      10902
# is_original                  2221
# initial_info                12387
# damages                     12840
# state                           0
# color                       13549
# additional_text             10938
# type                            0
# dtype: int64

# %%
# Deleting any columns that wouldn't make sense for detecting type

training = df.drop(columns=["full_nr","state","ks","start", "end", "before_Christ","participants_role","participant","parish","value","museum_abbr","musealia_mark","musealia_seria_nr","musealia_queue_nr","musealia_additional_nr","collection_mark","collection_queue_nr","collection_additional_nr","element_count","is_original"])
testing = datatest.drop(columns=["full_nr","state","ks","start", "end", "before_Christ","participants_role","participant","parish","value","museum_abbr","musealia_mark","musealia_seria_nr","musealia_queue_nr","musealia_additional_nr","collection_mark","collection_queue_nr","collection_additional_nr","element_count","is_original"])

# %%
# Change everything but the id column to a string type

columns = training.columns.values.tolist()[1:]
for col in columns:
  training[col] = training[col].astype("string")

columns2 = testing.columns.values.tolist()[1:]
for col in columns2:
  testing[col] = testing[col].astype("string")

# %%
# Encoding the data for use in algorithms

from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(handle_unknown="ignore", categories="auto")
# Encoder for training data

training = training.drop(columns=["type"]).fillna("")
tr_encoder = ohe.fit_transform(training)

# Encoder for testing data
testing = testing.fillna("")
te_encoder = ohe.transform(testing)

# %%
# !!! Cell for testing the accuracy of algorithm using the given training data

# Import the DecisionTreeClassifier class
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from numpy import array

X = tr_encoder
y = df.iloc[:,-1].values

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=68)

# Train a decision tree classifier on the typed data
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Use the trained classifier to make predictions on the typed test data
y_pred = clf.predict(X_test)
print(y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("")
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# ['pitser/templijäljend' 'foto' 'kava' ... 'fotonegatiiv' 'noodid' 'foto']
#
# Accuracy: 0.77

# %%
# !!! Actual Decision Tree training, using the whole training data to train the algorithm

# Import the DecisionTreeClassifier class
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from numpy import array

# Training and testing data
X_train2 = tr_encoder
y_train2 = df.iloc[:,-1].values

X_test2 = te_encoder

# Train a decision tree classifier on the typed data
clf2 = DecisionTreeClassifier()
clf2.fit(X_train2, y_train2)

# Use the trained classifier to make predictions on the typed test data
y_pred2 = clf2.predict(X_test2)

# %%
# Showing the prediction results

d = {"id" : testing["id"].values.tolist(), "type" : y_pred2}
test = pd.DataFrame(data=d)
test
# Out:
#            id                 type
# 0     2652198                 foto
# 1     3851731                paber
# 2     1211338                kleit
# 3      231244            silt/märk
# 4     2523607                 münt
# ...       ...                  ...
# 5995  3035795                 foto
# 5996  2765287               plakat
# 5997  2416520               raamat
# 5998  2327407  arheoloogiline leid
# 5999  2781747         fotonegatiiv
#
# [6000 rows x 2 columns]
